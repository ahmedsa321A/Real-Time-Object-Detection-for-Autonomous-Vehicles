# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ahmedsa321/bd100k-yolo-conveted")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/ahmedsa321/bd100k-yolo-conveted/versions/1

# %%
source_dir = "/root/.cache/kagglehub/datasets/ahmedsa321/bd100k-yolo-conveted/versions/1"
dest_dir = "/content/sample_data"

# !mv {source_dir}/* {dest_dir}/

print(f"Files moved from {source_dir} to {dest_dir}")
# Out:
# Files moved from /root/.cache/kagglehub/datasets/ahmedsa321/bd100k-yolo-conveted/versions/1 to /content/sample_data
