# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ahmedsa321/bd100k-yolo-conveted")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/ahmedsa321/bd100k-yolo-conveted/versions/1

# %%
source_dir = "/content/YOLO_Training_Results/bdd100k_colab_run3"
dest_dir = "/content/drive/MyDrive/Classroom"

# !mv {source_dir}/* {dest_dir}/

print(f"Files moved from {source_dir} to {dest_dir}")
# Out:
# Files moved from /content/YOLO_Training_Results/bdd100k_colab_run3 to /content/drive/MyDrive/Classroom

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO


model_to_resume = '/content/last.pt'


model = YOLO(model_to_resume)

results = model.train(resume=True)

print("Training has been resumed successfully!")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/content/best.pt")

# Export the model to ONNX format
# This creates a file named 'best.onnx'
success = model.export(format="onnx")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv12n summary (fused): 159 layers, 2,560,238 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 22, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<=1.19.1', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 14 packages in 285ms
# ...
